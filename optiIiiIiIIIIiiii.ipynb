# %% [markdown]
# <a href="https://colab.research.google.com/github/dino-ali/olamor/blob/main/optiIiiIiIIIIiiii.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np #calculos numericos
import pandas as pd #manejo de datos
import matplotlib.pyplot as plt #visualizaciones
import seaborn as sns #visualizaciones

from sklearn.preprocessing import StandardScaler #normalizar y escalar datos
from sklearn.model_selection import train_test_split #partir datos de testeo y entrenamiento
from sklearn.linear_model import LinearRegression #regresion lienal xd.
from sklearn.metrics import mean_absolute_error, mean_squared_error #metricas para evaluar la regresión.

# %%
data = pd.read_csv('/content/2021.Vans_Aggregated.csv') #busca el archivo y lo lee

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 19 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Manufacturer                                       40 non-null     object
#  1   Fuel Type                                          40 non-null     object
#  2   Number of vehicles                                 40 non-null     int64
#  3   OBFCM Fuel consumption (l/100 km)                  40 non-null     float64
#  4   WLTP Fuel consumption (l/100 km)                   40 non-null     float64
#  5   absolute gap Fuel consumption (l/100 km)           40 non-null     float64
#  6   percentage gap Fuel consumption (%)                40 non-null     float64
#  7   OBFCM CO2 emissions (g/km)                         40 non-null     float64
# ...

# %%
data.head(10) #encabezado que me da los diez primeros valores
# Out:
#           Manufacturer        Fuel Type  Number of vehicles  \
# 0               BMW AG           DIESEL                   1
# 1             CHRYSLER           PETROL                   5
# 2                  PSA           PETROL                  89
# 3                VOLVO           PETROL                  31
# 4      OPEL AUTOMOBILE           DIESEL                   6
# 5                 SEAT           DIESEL                   4
# 6                VOLVO           DIESEL                  11
# 7              RENAULT           PETROL                   3
# 8  AUTOMOBILES PEUGEOT  PETROL/ELECTRIC                   1
# 9           FIAT GROUP  PETROL/ELECTRIC                   1
#
#    OBFCM Fuel consumption (l/100 km)  WLTP Fuel consumption (l/100 km)  \
# 0                               6.96                              6.04
# 1                               8.29                              6.59
# 2                               8.31                              6.98
# ...

# %%
data2 = pd.get_dummies(data) #dumificar: variables categoricas se convierten en variables numericas.
print(data2)

# %%
print(data.shape)
# Out:
# (40, 14)

# %%
data = data.drop(labels = ['Manufacturer', 'Fuel Type', 'absolute gap Fuel consumption weighted (l/100 km)', 'WLTP CO2 emissions weighted (g/km)', 'OBFCM CO2 emissions weighted (g/km)'], axis = 1)

# %%
data.corr()

# %%
x = data.drop('percentage gap CO2 emissions (%)', axis = 1) #no puedo tener la variable que voy a predecir (función objetivo)
y = data['percentage gap CO2 emissions (%)']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = 123)

# %%
sc = StandardScaler()
x_train_sc = sc.fit_transform(x_train)
x_test_sc = sc.transform(x_test)

# %%
lr = LinearRegression()
lr.fit(x_train_sc, y_train)
y_pred = lr.predict(x_test_sc)
print(y_pred)
# Out:
# [ 7.   13.38 11.81 31.59 15.87 17.66 -5.35 25.68]

# %%
print(mean_squared_error(y_test, y_pred))
print(mean_absolute_error(y_test, y_pred))
# Out:
# 3.1806871698511196e-27
# 4.8405723873656825e-14
